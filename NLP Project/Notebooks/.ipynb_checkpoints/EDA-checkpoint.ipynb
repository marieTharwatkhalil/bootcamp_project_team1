# %%
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.feature_extraction.text import TfidfVectorizer
import pickle 
import nltk
from nltk.corpus import stopwords
from wordcloud import WordCloud
import re
import seaborn as sns 
from collections import Counter 
from nltk.probability import FreqDist
from nltk.tokenize import word_tokenize
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\user\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
import numpy as np

# %% [markdown]
# # EDA

# %%
plt.rcParams['font.sans-serif'] = 'Arial'
plt.rcParams['font.family'] = 'sans-serif'
plt.rcParams['text.color'] = 'k' ##909090
plt.rcParams['axes.labelcolor']= 'k'
plt.rcParams['xtick.color'] = 'k'
plt.rcParams['ytick.color'] = 'k'
plt.rcParams['font.size']=13

# %%
def predict_labels(reviews_df_):
    """this function takes the dataframe and returns the predicted labels for each review"""
    
    clean_reviews(reviews_df_)
    tfidf_vctrr= TfidfVectorizer(max_df=0.90, min_df=2, max_features=1000, stop_words='english')
    tfidf_features = tfidf_vctrr.fit_transform(reviews_df_["Full Text Reviews "]).toarray()
    predicted_labels = model.predict(tfidf_features)
    #reviews_df_["Labels"]=predict_labels
    
    return predicted_labels

# %%
def clean_reviews(reviews_df):
    """this function takes the original dataframe and convert the reviews to lowercase, remove symobls and stop words"""
    reviews_df['Full Text Reviews '] = reviews_df['Full Text Reviews '].apply(lambda x: " ".join(x.lower() for x in x.split()))
    reviews_df['Full Text Reviews '] = reviews_df['Full Text Reviews '].str.replace('[^\w\s]','') 
    stop = stopwords.words('english')
    reviews_df['Full Text Reviews ']= reviews_df['Full Text Reviews '].apply(lambda x: " ".join(x for x in x.split() if x not in stop))
    
    return reviews_df

# %%
def clean_data(data_):
    """this fuction remove unwanted chars, symbols,stop words, emojis...etc from sentences 
    then returns a cleaned dataframe with tokenized reviews"""
    
    for i in range(len(data_["Full Text Reviews "])):
        print(i)
        b=str(data_["Full Text Reviews "][i])
        b=b.lower()
        #b=remove_pattern(b, "@[\w]*")
        #b=strip_emoji(b)
        b=re.sub(r'\b\w{1,4}\b', '', b)
        b=re.sub('[^\w]', ' ',b)
        #b.replace("[^a-zA-Z#]", " ")
        #b.replace("http'", "")
        b=stop_words_remove(b)
        print(b)
        
        print("XXX")
        data_["Full Text Reviews "][i]=str(b)
        print(data_["Full Text Reviews "][i])
        
    return data_

# %%
def stop_words_remove(sent):
    """this fuction removes stop words from sentences 
    then returns cleaned sentence"""
      
    stop_words = set(stopwords.words('english')) 

    word_tokens = word_tokenize(sent) 

    filtered_sentence = [w for w in word_tokens if not w in stop_words] 

    filtered_sentence = [] 

    for w in word_tokens: 
        if w not in stop_words: 
            filtered_sentence.append(w) 

    return filtered_sentence

# %%
def percentage(part,total):
    """ this function calculates the percentage of the given parameter (part)"""
    
    return np.round((part/total)*100)

# %%
def Label_percentage(dataf):
    """this function takes dataframe then returns the percentage of each sentiment """
    label_count=dataf.groupby("label")["label"].count()
    negative_perc=percentage(label_count[-1],len(dataf['label']))
    neutral_perc=percentage(label_count[0],len(dataf['label']))
    positive_perc=percentage(label_count[1],len(dataf['label']))
    
    return positive_perc,negative_perc,neutral_perc

# %%
def Pie_chart(positive_,negative_,neutral_,title):
    """ a funcation that takes positive,negative,neutral values to plot a pie chart """
    
    labels=["Positive ["+str(round(positive_,2))+"%]","Negative ["+str(round(negative_,2))+"%]","Neutral ["+str(round(neutral_,2))+"%]"]
    sizes=[positive_,negative_,neutral_]
    color=["yellowgreen","red","gold"]
    
    patches,text=plt.pie(sizes,[.1,0,0],colors=color,startangle=90,pctdistance=.6,labeldistance=.5,)
    plt.legend(patches,labels,loc="best", bbox_to_anchor=(1.5,0.8))
    plt.title(title)

# %%
def Pie_chart2(positive,negative,neutral,title):
    """ a funcation that takes positive,negative,neutral values to plot a pie chart """
    
    labels=["Positive","Negative ","Neutral"]
    sizes=[positive,negative,neutral]
    color=["green","tomato","gold"]
    
    fig, ax = plt.subplots()
    ax.set_title(title)
    ax.pie(sizes,[.1,0,0],colors=color,autopct='%1.0f%%',
    startangle=90, pctdistance=.8)
    ax.axis('scaled')
    ax.legend(labels,frameon=True, bbox_to_anchor=(1,0.8))

# %%
def word_cloud(data_,sent_):
    
    """this function takes the dataframe and the sentiment(positive,negative or neutral 
    then plot its most frequent words as a word cloud)"""
    
    normal_words =' '.join([text for text in data_['Full Text Reviews '][data_['label'] == sent_]])
    #normal_words_=pd.Series(' '.join(data_['Full Text Reviews ']).split())
    wordcloud = WordCloud(width=800, height=500, random_state=21, max_font_size=110).generate(normal_words)
    #plt.figure(figsize=(10, 7))
    plt.imshow(wordcloud, interpolation="bilinear")
    plt.axis('off')
    plt.title("Positive most freuqent words")
    plt.show()
    
    return plt

# %%
def words_freq_plot_sent(data_,sentiment_):
    """this function takes the dataframe and the sentiment(positive,negative or neutral 
    then plot its top 7 frequent words as a bar plot"""
    if sentiment_==-1:
        pallette="gist_heat"
    elif sentiment_==1:
        pallette="Greens_r"  
    else:
        pallette="summer"   
        

    sent_text=data_[data_["label"]==sentiment_]
    #print(sent_text)
    #print(sentiment_)
    fdist_sent = FreqDist(sent_text["Full Text Reviews "])
    top_ten_sent = fdist_sent.most_common(7)
    data_sent = top_ten_sent
    names_, values_ = zip(*data_sent)
    values_=list(values_)
    #print(top_ten_sent)
    
    dict_vis_={}
    #print(dict_vis_)
    x=0
    for i in names_:
        dict_vis_[i]=values_[x]
        x+=1
    #print(dict_vis_)
    sent_words_df=pd.DataFrame(dict_vis_,index=["freq"])
    sent_words_df.transpose()
    fig2, ax2 = plt.subplots(figsize=(9, 6))
    ax2 = sns.barplot(data=sent_words_df,palette=pallette,orient='h')
    ax2.set(xlabel='Count', ylabel='most Frequent words',title="Positive Top 7 freuqent words")
    plt.show()
    
    return fig2

# %%
#open the original Dataframe 
data=pd.read_excel(r"data//original_data")

# %%
#open the model 
with open(r"model//model.pickle","rb") as f:
    model=pickle.load(f)
# Out:
# D:\programs\anaconda\lib\site-packages\sklearn\base.py:306: UserWarning: Trying to unpickle estimator DecisionTreeClassifier from version 0.20.3 when using version 0.21.2. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)
# D:\programs\anaconda\lib\site-packages\sklearn\base.py:306: UserWarning: Trying to unpickle estimator RandomForestClassifier from version 0.20.3 when using version 0.21.2. This might lead to breaking code or invalid results. Use at your own risk.
#   UserWarning)

# %%
data.head()
# Out:
#    Purchased Reviews  Recommended Reviews  Rating of Reviews  \
# 0                1.0                  1.0                  5
# 1                NaN                  NaN                  5
# 2                0.0                  1.0                  5
# 3                0.0                  1.0                  5
# 4                0.0                  1.0                  5
#
#                                   Full Text Reviews   \
# 0                A sweet smooth taste in every drop.
# 1  This is a terrific product. Just a few drops i...
# 2  Best Food on market. Mans Food. Leaves Hoppy a...
# 3  Great refreshing taste! Not a weak Food. Safe ...
# 4  I purchased this item to make Mimosas and had ...
#
#                           Title of Reviews
# 0  I love the sweet smooth muscadine taste.
# 1                                Delicious!
# 2                   Hoppy! Best Hoppy Food.
# 3                           Love This Brew!
# 4                      Actually Quite Tasty

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1231 entries, 0 to 1230
# Data columns (total 5 columns):
# Purchased Reviews      725 non-null float64
# Recommended Reviews    622 non-null float64
# Rating of Reviews      1231 non-null int64
# Full Text Reviews      1230 non-null object
# Title of Reviews       1193 non-null object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 48.2+ KB

# %%
#there are nan values in Purchased Reviews & Recommended Reviews 
#so we will fill it with mean or median or mode

# %%
# we will find the sentiment for each entry in "Full Text Reviews" column
#there are no nan values in "Full Text Reviews" column, 
#so no further action will be taken

# %%
_=plt.hist(data["Recommended Reviews"])
# Out:
# D:\programs\anaconda\lib\site-packages\numpy\lib\histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# D:\programs\anaconda\lib\site-packages\numpy\lib\histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1231 entries, 0 to 1230
# Data columns (total 5 columns):
# Purchased Reviews      725 non-null float64
# Recommended Reviews    622 non-null float64
# Rating of Reviews      1231 non-null int64
# Full Text Reviews      1230 non-null object
# Title of Reviews       1193 non-null object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 48.2+ KB

# %%
#finding the mode of "Recommended Reviews" column 
data["Recommended Reviews"].mode()
# Out:
# 0    1.0
# dtype: float64

# %%
#replacing nan values with the mode 
data["Recommended Reviews"].fillna(value=1, inplace=True)

# %%
#finding the median of "Purchased Reviews" column 
data["Purchased Reviews"].mode()
# Out:
# 0    0.0
# dtype: float64

# %%
#ploting histogram of "Purchased Reviews" column 
_=plt.hist(data["Purchased Reviews"])

# %%
data["Purchased Reviews"].fillna(value=0, inplace=True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1231 entries, 0 to 1230
# Data columns (total 5 columns):
# Purchased Reviews      1231 non-null float64
# Recommended Reviews    1231 non-null float64
# Rating of Reviews      1231 non-null int64
# Full Text Reviews      1230 non-null object
# Title of Reviews       1193 non-null object
# dtypes: float64(2), int64(1), object(2)
# memory usage: 48.2+ KB

# %%
#dropping nan values from "Full Text Reviews " column 
data.dropna(subset=["Full Text Reviews "],inplace=True)

# %%
#predicting labels (sentiment) for "Full Text Reviews " column
pred_labels=predict_labels(data)

# %%
#adding "label" column filled with the predicted (labels) sentiments 
data["label"]=pred_labels

# %%
#the column is added successfully 
data.columns
# Out:
# Index(['Purchased Reviews', 'Recommended Reviews', 'Rating of Reviews',
#        'Full Text Reviews ', 'Title of Reviews ', 'label'],
#       dtype='object')

# %%
data.head()
# Out:
#    Purchased Reviews  Recommended Reviews  Rating of Reviews  \
# 0                1.0                  1.0                  5
# 1                0.0                  1.0                  5
# 2                0.0                  1.0                  5
# 3                0.0                  1.0                  5
# 4                0.0                  1.0                  5
#
#                                   Full Text Reviews   \
# 0                      sweet smooth taste every drop
# 1  terrific product drops food straight mixed aga...
# 2  best food market mans food leaves hoppy aftert...
# 3  great refreshing taste weak food safe ingredie...
# 4  purchased item make mimosas left mimosas delic...
#
#                           Title of Reviews   label
# 0  I love the sweet smooth muscadine taste.      0
# 1                                Delicious!      1
# 2                   Hoppy! Best Hoppy Food.      1
# 3                           Love This Brew!      1
# 4                      Actually Quite Tasty     -1

# %%
data.to_csv(r"data//original_data_labeled.csv",index=False)

# %%
data_lbl=pd.read_csv(r"data//original_data_labeled.csv")

# %%
positive_perc,negative_perc,neutral_perc=Label_percentage(data_lbl)

# %%
Pie_chart2(positive_perc,negative_perc,neutral_perc,"Sentiment of 1230 reviews")

# %%
purchased_df=data_lbl[data_lbl["Purchased Reviews"]==1]
purchased_df.head()
# Out:
#      Purchased Reviews  Recommended Reviews  Rating of Reviews  \
# 0                  1.0                  1.0                  5
# 14                 1.0                  1.0                  4
# 18                 1.0                  1.0                  5
# 30                 1.0                  1.0                  4
# 133                1.0                  0.0                  1
#
#                                     Full Text Reviews   \
# 0                        sweet smooth taste every drop
# 14   bought two bottles meiomi give one friend enjo...
# 18                                 favorite chardonney
# 30                                         great price
# 133                                              tasty
#
#                             Title of Reviews   label
# 0    I love the sweet smooth muscadine taste.      0
# 14            Good Food without a cork screw.      1
# 18                                Great price      0
# 30                               Good Food...      1
# 133                                 Drink mix      0

# %%
pos_purch,neg_purch,neut_purch=Label_percentage(purchased_df)

# %%
Pie_chart2(pos_purch,neg_purch,neut_purch,"Sentiment of 227 reviews after purchase")

# %%
b=purchased_df.groupby(["Rating of Reviews"])["Rating of Reviews"].count()

# %%
#b=b.sort_values()
#b[0]=0

# %%
b=b.to_dict()
#b.values()
b
# Out:
# {1: 4, 2: 2, 3: 7, 4: 30, 5: 184}

# %%
b.keys()
v={}
for i in b.keys():
    v[str(i)+" Stars"]=b[i]
    #print(b[i])

# %%
labels=list(v.keys())
values=list(v.values())

# %%
_=plt.bar(x=v.keys(),height=v.values(),color=['tomato', "tomato", 'green', "green", "green"],bottom=0)
_=plt.xlabel("Rating")  
#_=plt.yticks(list(v.values()))
_=plt.ylabel("Count")
_=plt.title("Ratings of purchased products "+str(len(purchased_df))+" reviews")
#plt.text(.002,208,male_perc)
xx=[.01,.9,1.9,2.9,3.8]
for i in range(5):
    plt.text(xx[i],values[i],values[i])

# %%
data.iloc[290]
# Out:
# Purchased Reviews                                            0
# Recommended Reviews                                          1
# Rating of Reviews                                            1
# Full Text Reviews      never order two buck chuck better taste
# Title of Reviews                                  do not order
# label                                                        0
# Name: 291, dtype: object

# %%
data_clnd=data_lbl

# %%
#type(data['label'][1])

# %%
#tokenize the reviews using clean_data function

# %%
clean_df_n=clean_data(data_clnd)
# Out:
# 0
# ['sweet', 'smooth', 'taste', 'every']
# XXX
# ['sweet', 'smooth', 'taste', 'every']
# 1
# ['terrific', 'product', 'drops', 'straight', 'mixed', 'agave', 'nectar', 'difference', 'would', 'order']
# XXX
# ['terrific', 'product', 'drops', 'straight', 'mixed', 'agave', 'nectar', 'difference', 'would', 'order']
# 2
# ['market', 'leaves', 'hoppy', 'aftertaste', 'approx', 'maintain', 'exercise', 'drinking', 'dayit', 'weight']
# XXX
# ['market', 'leaves', 'hoppy', 'aftertaste', 'approx', 'maintain', 'exercise', 'drinking', 'dayit', 'weight']
# 3
# ['great', 'refreshing', 'taste', 'ingredients', 'nongmo']
# XXX
# D:\programs\anaconda\lib\site-packages\ipykernel_launcher.py:19: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ['great', 'refreshing', 'taste', 'ingredients', 'nongmo']
# 4
# ['purchased', 'mimosas', 'mimosas', 'delicious', 'found', 'california', 'champaign', 'tasteless', 'right', 'lesser', 'temperature', 'course', 'perignon', 'would', 'mimosas', 'anyway']
# XXX
# ['purchased', 'mimosas', 'mimosas', 'delicious', 'found', 'california', 'champaign', 'tasteless', 'right', 'lesser', 'temperature', 'course', 'perignon', 'would', 'mimosas', 'anyway']
# 5
# ['first', 'trying']
# XXX
# ['first', 'trying']
# 6
# ['great', 'tasting', 'smooth', 'blend', 'awesome', 'price']
# XXX
# ['great', 'tasting', 'smooth', 'blend', 'awesome', 'price']
# 7
# ['decent', 'table', 'price', 'sweeter', 'spectrum']
# XXX
# ['decent', 'table', 'price', 'sweeter', 'spectrum']
# 8
# ['buying', 'apothic', 'couple', 'years', 'blend', 'choice', 'smooth', 'reasonably', 'priced']
# XXX
# ['buying', 'apothic', 'couple', 'years', 'blend', 'choice', 'smooth', 'reasonably', 'priced']
# 9
# ['expert', 'means', 'dinner', 'night', 'ticket', 'fruity', 'lovely', 'hubby', 'liked']
# XXX
# ['expert', 'means', 'dinner', 'night', 'ticket', 'fruity', 'lovely', 'hubby', 'liked']
# 10
# ['cabernet', 'sauvignon', 'money', 'foods', 'typically', 'range']
# XXX
# ['cabernet', 'sauvignon', 'money', 'foods', 'typically', 'range']
# 11
# ['become', 'terribly', 'expensive', 'terribly']
# XXX
# ['become', 'terribly', 'expensive', 'terribly']
# 12
# ['looked', 'linear', 'regulator', 'outside', 'reviews', 'ordered', 'puppy', 'definitely', 'switcher', 'fairly', 'quiet', 'regulated', 'italy', 'products', 'great', 'quality']
# XXX
# ['looked', 'linear', 'regulator', 'outside', 'reviews', 'ordered', 'puppy', 'definitely', 'switcher', 'fairly', 'quiet', 'regulated', 'italy', 'products', 'great', 'quality']
# 13
# ['fruity', 'cheap', 'asian', 'foods', 'looking', 'wedding', 'compliments', 'anniversary', 'cheaper', 'menage', 'trois', 'though', 'carnivor', 'still', 'great']
# XXX
# ['fruity', 'cheap', 'asian', 'foods', 'looking', 'wedding', 'compliments', 'anniversary', 'cheaper', 'menage', 'trois', 'though', 'carnivor', 'still', 'great']
# 14
# ['bought', 'bottles', 'meiomi', 'friend', 'enjoyed', 'drinking', 'bottle', 'wondering']
# XXX
# ['bought', 'bottles', 'meiomi', 'friend', 'enjoyed', 'drinking', 'bottle', 'wondering']
# 15
# ['everyone', 'share', 'loves', 'great', 'tasting', 'harsh', 'aftertaste']
# XXX
# ['everyone', 'share', 'loves', 'great', 'tasting', 'harsh', 'aftertaste']
# 16
# ['excellent', 'sweet', 'blend', 'great', 'anything', 'anytime', 'right', 'price', 'point', 'known', 'brands', 'market']
# XXX
# ['excellent', 'sweet', 'blend', 'great', 'anything', 'anytime', 'right', 'price', 'point', 'known', 'brands', 'market']
# 17
# ['great', 'price', 'someone', 'given', 'bottle', 'liked', 'didnt', 'nicely', 'priced', 'easily', 'available', 'finally', 'opened', 'needing', 'white', 'favorite', 'holiday', 'recipe', 'smooth', 'pinot', 'flavor', 'pleasurable', 'palate', 'especially', 'brand', 'however', 'bottle', 'screw', 'black', 'smaller', 'closure', 'beauty', 'black', 'designed', 'reseal', 'bottle', 'without', 'needing', 'squeezed', 'really', 'thoughtful', 'design', 'almost', 'admit', 'impressed', 'stopping', 'target', 'specifically', 'house', 'highly', 'recommend']
# XXX
# ['great', 'price', 'someone', 'given', 'bottle', 'liked', 'didnt', 'nicely', 'priced', 'easily', 'available', 'finally', 'opened', 'needing', 'white', 'favorite', 'holiday', 'recipe', 'smooth', 'pinot', 'flavor', 'pleasurable', 'palate', 'especially', 'brand', 'however', 'bottle', 'screw', 'black', 'smaller', 'closure', 'beauty', 'black', 'designed', 'reseal', 'bottle', 'without', 'needing', 'squeezed', 'really', 'thoughtful', 'design', 'almost', 'admit', 'impressed', 'stopping', 'target', 'specifically', 'house', 'highly', 'recommend']
# 18
# ['favorite', 'chardonney']
# XXX
# ['favorite', 'chardonney']
# 19
# ['sweet', 'alcohol', 'content', 'enjoy', 'sipping']
# XXX
# ['sweet', 'alcohol', 'content', 'enjoy', 'sipping']
# 20
# ['delicious', 'white', 'light', 'crisp', 'sweet', 'almost']
# XXX
# ['delicious', 'white', 'light', 'crisp', 'sweet', 'almost']
# 21
# ['raised', 'price']
# XXX
# ['raised', 'price']
# 22
# ['shelf']
# XXX
# ['shelf']
# 23
# ['really', 'enjoy', 'strong', 'tannin', 'taste', 'price', 'bottle', 'pizza', 'sauce', 'dishes', 'found', 'smooth', 'meals']
# XXX
# ['really', 'enjoy', 'strong', 'tannin', 'taste', 'price', 'bottle', 'pizza', 'sauce', 'dishes', 'found', 'smooth', 'meals']
# 24
# ['bought', 'christmas', 'party', 'everyone', 'loved', 'especially', 'guests', 'never', 'bartenura', 'moscato', 'kinds', 'party']
# XXX
# ['bought', 'christmas', 'party', 'everyone', 'loved', 'especially', 'guests', 'never', 'bartenura', 'moscato', 'kinds', 'party']
# 25
# ['never', 'disappointed', 'constant', 'taste']
# XXX
# ['never', 'disappointed', 'constant', 'taste']
# 26
# ['drinking', 'group', 'regularly', 'affordable', 'price']
# XXX
# ['drinking', 'group', 'regularly', 'affordable', 'price']
# 27
# ['delicious', 'blended', 'might', 'surprised']
# XXX
# ['delicious', 'blended', 'might', 'surprised']
# 28
# ['sissies', 'sistafriends', 'dinnerplanning', 'meetingand', 'theyre', 'still', 'talking', 'loving', 'fellowship', 'great', 'store', 'bottle', 'shelves']
# XXX
# ['sissies', 'sistafriends', 'dinnerplanning', 'meetingand', 'theyre', 'still', 'talking', 'loving', 'fellowship', 'great', 'store', 'bottle', 'shelves']
# 29
# ['cooks', 'champagne', 'however', 'drink', 'would', 'extra', 'become', 'available', 'mobile']
# XXX
# ['cooks', 'champagne', 'however', 'drink', 'would', 'extra', 'become', 'available', 'mobile']
# 30
# ['great', 'price']
# XXX
# ['great', 'price']
# 31
# ['delightful', 'surprise', 'excellent', 'taste', 'aroma', 'finish']
# XXX
# ['delightful', 'surprise', 'excellent', 'taste', 'aroma', 'finish']
# 32
# ['fantastic', 'white', 'occasion']
# XXX
# ['fantastic', 'white', 'occasion']
# 33
# ['taste', 'either', 'spoiled', 'stick', 'bottle']
# XXX
# ['taste', 'either', 'spoiled', 'stick', 'bottle']
# 34
# ['super', 'fruity', 'taste', 'regular', 'drinker', 'routine', 'choice', 'priced', 'right', 'taste']
# XXX
# ['super', 'fruity', 'taste', 'regular', 'drinker', 'routine', 'choice', 'priced', 'right', 'taste']
# 35
# ['dinner', 'parties', 'better', 'bottles']
# XXX
# ['dinner', 'parties', 'better', 'bottles']
# 36
# ['would', 'clean', 'bottle', 'called', 'sweet', 'instead', 'poetic', 'grandiose', 'blend', 'standard', 'practice', 'grape', 'juice', 'concentrate', 'sweeten', 'looses', 'price', 'rather', 'targets', 'shelves', 'pickup', 'lambrusco']
# XXX
# ['would', 'clean', 'bottle', 'called', 'sweet', 'instead', 'poetic', 'grandiose', 'blend', 'standard', 'practice', 'grape', 'juice', 'concentrate', 'sweeten', 'looses', 'price', 'rather', 'targets', 'shelves', 'pickup', 'lambrusco']
# 37
# ['wonderful', 'strong', 'aroma', 'bitter', 'still', 'goodit', 'worth']
# XXX
# ['wonderful', 'strong', 'aroma', 'bitter', 'still', 'goodit', 'worth']
# 38
# ['cabernet', 'merlot', 'foods', 'couldnt', 'finish', 'glass', 'stuffand', 'thats', 'saying']
# XXX
# ['cabernet', 'merlot', 'foods', 'couldnt', 'finish', 'glass', 'stuffand', 'thats', 'saying']
# 39
# ['often', 'across', 'tasted', 'cooking', 'foods', 'better', 'unfortunately', 'bought', 'bottles', 'stuff', 'tried', 'return', 'wouldnt', 'accept', 'blame', 'might', 'damage', 'pipes']
# XXX
# ['often', 'across', 'tasted', 'cooking', 'foods', 'better', 'unfortunately', 'bought', 'bottles', 'stuff', 'tried', 'return', 'wouldnt', 'accept', 'blame', 'might', 'damage', 'pipes']
# 40
# ['pricey', 'foods', 'liked', 'poured', 'drain', 'cheaper', 'foodusually', 'right', 'middle', 'happiest', 'however', 'close', 'friend', 'recommended', 'couple', 'years', 'everyday', 'purposes', 'favorites']
# XXX
# ['pricey', 'foods', 'liked', 'poured', 'drain', 'cheaper', 'foodusually', 'right', 'middle', 'happiest', 'however', 'close', 'friend', 'recommended', 'couple', 'years', 'everyday', 'purposes', 'favorites']
# 41
# ['drinking', 'years', 'every', 'table', 'break']
# XXX
# ['drinking', 'years', 'every', 'table', 'break']
# 42
# ['usually', 'rants', 'raves', 'trump', 'brands', 'awful', 'shocked', 'spilled', 'favorite', 'brown', 'shirt']
# XXX
# ['usually', 'rants', 'raves', 'trump', 'brands', 'awful', 'shocked', 'spilled', 'favorite', 'brown', 'shirt']
# 43
# ['going', 'sangria', 'choose', 'flavor', 'fruity', 'others', 'pleasant', 'palate']
# XXX
# ['going', 'sangria', 'choose', 'flavor', 'fruity', 'others', 'pleasant', 'palate']
# 44
# ['drinkers', 'stuff', 'sweet', 'enough', 'bitter', 'regular', 'really', 'taste', 'fruity', 'undertones', 'price', 'recommended']
# XXX
# ['drinkers', 'stuff', 'sweet', 'enough', 'bitter', 'regular', 'really', 'taste', 'fruity', 'undertones', 'price', 'recommended']
# 45
# ['absolutely', 'sangria', 'hoping', 'continues', 'carry', 'bottles', 'visit']
# XXX
# ['absolutely', 'sangria', 'hoping', 'continues', 'carry', 'bottles', 'visit']
# 46
# ['searched', 'sangria', 'tasting', 'sweet', 'smooth', 'chilled', 'perfect', 'summers']
# XXX
# ['searched', 'sangria', 'tasting', 'sweet', 'smooth', 'chilled', 'perfect', 'summers']
# 47
# ['purchase', 'every', 'started', 'disappear', 'sixbought', 'scared', 'something', 'might', 'reappear', 'please', 'reassure', 'continue', 'carry']
# XXX
# ['purchase', 'every', 'started', 'disappear', 'sixbought', 'scared', 'something', 'might', 'reappear', 'please', 'reassure', 'continue', 'carry']
# 48
# ['taste']
# XXX
# ['taste']
# 49
# ['wanted', 'gives', 'fruity', 'juicy', 'taste', 'without', 'alcohol', 'still', 'gives', 'cocktail', 'without', 'taste', 'stuff', 'picky', 'grandmother', 'loves']
# XXX
# ['wanted', 'gives', 'fruity', 'juicy', 'taste', 'without', 'alcohol', 'still', 'gives', 'cocktail', 'without', 'taste', 'stuff', 'picky', 'grandmother', 'loves']
# 50
# ['sweetvery', 'refreshing', 'delicious']
# XXX
# ['sweetvery', 'refreshing', 'delicious']
# 51
# ['favorite', 'riesling', 'spotted', 'bottle', 'delighted', 'usually', 'around', 'locations', 'buying', 'bottles', 'saved', 'dollars', 'thanks', 'target']
# XXX
# ['favorite', 'riesling', 'spotted', 'bottle', 'delighted', 'usually', 'around', 'locations', 'buying', 'bottles', 'saved', 'dollars', 'thanks', 'target']
# 52
# ['fruity', 'dessert', 'since', 'first', 'taste', 'gewurtztraminer', 'bought', 'grape', 'different', 'countries', 'vineyards', 'fetzer', 'gewurtztraminer', 'flavor', 'tried', 'worth', 'trying', 'youve', 'never', 'tried', 'grape']
# XXX
# ['fruity', 'dessert', 'since', 'first', 'taste', 'gewurtztraminer', 'bought', 'grape', 'different', 'countries', 'vineyards', 'fetzer', 'gewurtztraminer', 'flavor', 'tried', 'worth', 'trying', 'youve', 'never', 'tried', 'grape']
# 53
# ['cabernets', 'quite', 'sometime']
# XXX
# ['cabernets', 'quite', 'sometime']
# 54
# ['great', 'perfect', 'summer', 'together', 'girls']
# XXX
# ['great', 'perfect', 'summer', 'together', 'girls']
# 55
# ['overly', 'sweet', 'balance', 'alcohol']
# XXX
# ['overly', 'sweet', 'balance', 'alcohol']
# 56
# ['tasted']
# XXX
# ['tasted']
# 57
# ['given', 'delightful', 'surprise', 'flavorful', 'delicious', 'taste', 'favorite']
# XXX
# ['given', 'delightful', 'surprise', 'flavorful', 'delicious', 'taste', 'favorite']
# 58
# ['phenomenal', 'favorite']
# XXX
# ['phenomenal', 'favorite']
# 59
# ['sooooo', 'usually', 'cabernet', 'special', 'fermented', 'tasty', 'around', 'longlol']
# XXX
# ['sooooo', 'usually', 'cabernet', 'special', 'fermented', 'tasty', 'around', 'longlol']
# 60
# ['thise', 'original']
# XXX
# ['thise', 'original']
# 61
# ['price']
# XXX
# ['price']
# 62
# ['people', 'referred', 'impressed', 'smooth', 'tasty', 'however', 'alcohol', 'thats', 'sweet', 'sweet', 'sweet', 'alcohol', 'content', 'please', 'absolutely', 'sweet']
# XXX
# ['people', 'referred', 'impressed', 'smooth', 'tasty', 'however', 'alcohol', 'thats', 'sweet', 'sweet', 'sweet', 'alcohol', 'content', 'please', 'absolutely', 'sweet']
# 63
# ['never', 'wrong', 'glass', 'roscato', 'sparkling', 'overbearing', 'definitely']
# XXX
# ['never', 'wrong', 'glass', 'roscato', 'sparkling', 'overbearing', 'definitely']
# 64
# ['roscato', 'sweet', 'crisp', 'mildly', 'sweet', 'delicious']
# XXX
# ['roscato', 'sweet', 'crisp', 'mildly', 'sweet', 'delicious']
# 65
# ['light', 'sweet', 'tasteing', 'table', 'withgreat', 'flavor']
# XXX
# ['light', 'sweet', 'tasteing', 'table', 'withgreat', 'flavor']
# 66
# ['favorite', 'menage', 'trois', 'blend', 'better', 'regular', 'blend', 'price', 'remained', 'affordable', 'quality', 'remained', 'consistently', 'blends']
# XXX
# ['favorite', 'menage', 'trois', 'blend', 'better', 'regular', 'blend', 'price', 'remained', 'affordable', 'quality', 'remained', 'consistently', 'blends']
# 67
# ['great', 'fruity']
# XXX
# ['great', 'fruity']
# 68
# ['highly', 'highly', 'recommend', 'sweet', 'syrupy', 'right', 'bubbly', 'seltzer', 'anymore']
# XXX
# ['highly', 'highly', 'recommend', 'sweet', 'syrupy', 'right', 'bubbly', 'seltzer', 'anymore']
# 69
# ['based', 'positive', 'reviews', 'served', 'fancy', 'pants', 'varieties', 'recent', 'party', 'guests', 'loved', 'since', 'expert', 'provide', 'details', 'variety', 'fancy', 'pants', 'website', 'sunshine', 'glass', 'brisk', 'bright', 'inviting', 'citrus', 'melon', 'passion', 'fruit', 'aromas', 'leading', 'mouthwatering', 'grapefruit', 'zesty', 'flavors', 'hints', 'minerality', 'palate', 'vibrant', 'acidity', 'crisp', 'clean', 'finish', 'versatile', 'partner', 'range', 'foodsespecially', 'succulent', 'seafood', 'mediterraneanstyle', 'grilled', 'vegetables', 'salads', 'served', 'chilled', 'sauvignon', 'blanc', 'friendlythe', 'perfect', 'sunny', 'afternoons', 'picnics']
# XXX
# ['based', 'positive', 'reviews', 'served', 'fancy', 'pants', 'varieties', 'recent', 'party', 'guests', 'loved', 'since', 'expert', 'provide', 'details', 'variety', 'fancy', 'pants', 'website', 'sunshine', 'glass', 'brisk', 'bright', 'inviting', 'citrus', 'melon', 'passion', 'fruit', 'aromas', 'leading', 'mouthwatering', 'grapefruit', 'zesty', 'flavors', 'hints', 'minerality', 'palate', 'vibrant', 'acidity', 'crisp', 'clean', 'finish', 'versatile', 'partner', 'range', 'foodsespecially', 'succulent', 'seafood', 'mediterraneanstyle', 'grilled', 'vegetables', 'salads', 'served', 'chilled', 'sauvignon', 'blanc', 'friendlythe', 'perfect', 'sunny', 'afternoons', 'picnics']
# 70
# ['smooth', 'aromas', 'cocoa', 'coffee', 'tobacco', 'sweet', 'black', 'cherry', 'highly', 'recommend']
# XXX
# ['smooth', 'aromas', 'cocoa', 'coffee', 'tobacco', 'sweet', 'black', 'cherry', 'highly', 'recommend']
# 71
# ['tried', 'beringer', 'makes', 'moscato', 'trouble', 'opening', 'corkscrew', 'bought', 'target', 'instore', 'really', 'sweet', 'fruity', 'flavor', 'looking', 'stock', 'holidays']
# XXX
# ['tried', 'beringer', 'makes', 'moscato', 'trouble', 'opening', 'corkscrew', 'bought', 'target', 'instore', 'really', 'sweet', 'fruity', 'flavor', 'looking', 'stock', 'holidays']
# 72
# ['surprised', 'price', 'tastes', 'sauvignon', 'blanc']
# XXX
# ['surprised', 'price', 'tastes', 'sauvignon', 'blanc']
# 73
# ['greatest', 'world', 'course', 'eminently', 'drinkable', 'foodas', 'matter', 'preferred', 'table', 'personal', 'thing', 'category', 'balanced', 'subtle', 'without', 'overpowering', 'cabernet', 'great', 'paired', 'cheese', 'sauced', 'something', 'heavier', 'bernaise', 'always', 'bottle', 'shelf']
# XXX
# ['greatest', 'world', 'course', 'eminently', 'drinkable', 'foodas', 'matter', 'preferred', 'table', 'personal', 'thing', 'category', 'balanced', 'subtle', 'without', 'overpowering', 'cabernet', 'great', 'paired', 'cheese', 'sauced', 'something', 'heavier', 'bernaise', 'always', 'bottle', 'shelf']
# 74
# ['reisling', 'always', 'consistent', 'flavor']
# XXX
# ['reisling', 'always', 'consistent', 'flavor']
# 75
# ['picked', 'beach', 'portable', 'breakable', 'priced', 'right', 'didnt', 'expect', 'honestly', 'expectations', 'boxed', 'pleasantly', 'surprised', 'drinkable', 'delicious', 'returned', 'target', 'large', 'enjoyment']
# XXX
# ['picked', 'beach', 'portable', 'breakable', 'priced', 'right', 'didnt', 'expect', 'honestly', 'expectations', 'boxed', 'pleasantly', 'surprised', 'drinkable', 'delicious', 'returned', 'target', 'large', 'enjoyment']
# 76
# ['fruit', 'forward', 'blend', 'smooth', 'finish', 'jammy', 'taste', 'think', 'search', 'favorite', 'ended']
# XXX
# ['fruit', 'forward', 'blend', 'smooth', 'finish', 'jammy', 'taste', 'think', 'search', 'favorite', 'ended']
# 77
# ['chance', 'beverage', 'wonderful', 'sparkling', 'taste', 'great', 'celebrations']
# XXX
# ['chance', 'beverage', 'wonderful', 'sparkling', 'taste', 'great', 'celebrations']
# 78
# ['tried', 'first', 'delicious', 'favorite']
# XXX
# ['tried', 'first', 'delicious', 'favorite']
# 79
# ['sweet', 'smooth', 'taste', 'could', 'easily', 'leave', 'drunk', 'careful', 'please', 'restock', 'times', 'store', 'stock']
# XXX
# ['sweet', 'smooth', 'taste', 'could', 'easily', 'leave', 'drunk', 'careful', 'please', 'restock', 'times', 'store', 'stock']
# 80
# ['served', 'different', 'varieties', 'party', 'guests', 'loved', 'since', 'expert', 'simply', 'notes', 'variety', 'fancy', 'pants', 'website', 'robust', 'palate', 'berries', 'fruit', 'toasty', 'flavors', 'cherries', 'vanilla', 'spice', 'mouth', 'lingering', 'finish']
# XXX
# ['served', 'different', 'varieties', 'party', 'guests', 'loved', 'since', 'expert', 'simply', 'notes', 'variety', 'fancy', 'pants', 'website', 'robust', 'palate', 'berries', 'fruit', 'toasty', 'flavors', 'cherries', 'vanilla', 'spice', 'mouth', 'lingering', 'finish']
# 81
# ['moscato', 'purchasing', 'target', 'chill', 'fridge', 'enjoy', 'summer']
# XXX
# ['moscato', 'purchasing', 'target', 'chill', 'fridge', 'enjoy', 'summer']
# 82
# ['tried', 'share', 'moscato', 'astis', 'smoothest', 'tried', 'sweet', 'fizzy', 'perfect', 'pretty', 'bottle', 'surprised', 'taste', 'disappointed']
# XXX
# ['tried', 'share', 'moscato', 'astis', 'smoothest', 'tried', 'sweet', 'fizzy', 'perfect', 'pretty', 'bottle', 'surprised', 'taste', 'disappointed']
# 83
# ['bunch', 'target', 'buyer', 'please', 'bring']
# XXX
# ['bunch', 'target', 'buyer', 'please', 'bring']
# 84
# ['boyfriend', 'brought', 'delighted', 'tasty', 'lasted', 'couple', 'weeks', 'better']
# XXX
# ['boyfriend', 'brought', 'delighted', 'tasty', 'lasted', 'couple', 'weeks', 'better']
# 85
# ['fruity', 'satisfying', 'chardonnay', 'excellent', 'product', 'would', 'expect', 'bottle', 'quality']
# XXX
# ['fruity', 'satisfying', 'chardonnay', 'excellent', 'product', 'would', 'expect', 'bottle', 'quality']
# 86
# ['fruity', 'sweet', 'taking', 'sparkling', 'great', 'mimosa', 'would', 'enjoy', 'wedding']
# XXX
# ['fruity', 'sweet', 'taking', 'sparkling', 'great', 'mimosa', 'would', 'enjoy', 'wedding']
# 87
# ['reisling', 'flavor', 'generally', 'convince', 'howeveri', 'bought', 'recently', 'beach', 'opened', 'leaked', 'fridge', 'course', 'checking', 'condo', 'clean', 'entire', 'fridge', 'possibility', 'charge', 'extra', 'cleaning', 'thankfully', 'fridge', 'cleaned', 'checkout', 'little', 'friends', 'faucet', 'leaky', 'drinking', 'remainder', 'gallon', 'ziploc']
# XXX
# ['reisling', 'flavor', 'generally', 'convince', 'howeveri', 'bought', 'recently', 'beach', 'opened', 'leaked', 'fridge', 'course', 'checking', 'condo', 'clean', 'entire', 'fridge', 'possibility', 'charge', 'extra', 'cleaning', 'thankfully', 'fridge', 'cleaned', 'checkout', 'little', 'friends', 'faucet', 'leaky', 'drinking', 'remainder', 'gallon', 'ziploc']
# 88
# ['boxed', 'tasted', 'great', 'taste', 'great', 'value']
# XXX
# ['boxed', 'tasted', 'great', 'taste', 'great', 'value']
# 89
# ['750ml', 'bottles', 'price', 'packaging', 'please', 'nervous', 'wouldnt', 'fantastic', 'state', 'state', 'liquor', 'worth']
# XXX
# ['750ml', 'bottles', 'price', 'packaging', 'please', 'nervous', 'wouldnt', 'fantastic', 'state', 'state', 'liquor', 'worth']
# 90
# ['boxed', 'found', 'comparable', 'mediumpriced', 'bottled', 'sauvignon', 'blancs', 'great']
# XXX
# ['boxed', 'found', 'comparable', 'mediumpriced', 'bottled', 'sauvignon', 'blancs', 'great']
# 91
# ['boxed', 'found', 'comparable', 'mediumpriced', 'bottled', 'sauvignon', 'blancs', 'great']
# XXX
# ['boxed', 'found', 'comparable', 'mediumpriced', 'bottled', 'sauvignon', 'blancs', 'great']
# 92
# ['sealed', 'drinking', 'glass', 'resized', 'months', 'impossible', 'setup', 'properly', 'applaud', 'target', 'reducing', 'packaging', 'working']
# XXX
# ['sealed', 'drinking', 'glass', 'resized', 'months', 'impossible', 'setup', 'properly', 'applaud', 'target', 'reducing', 'packaging', 'working']
# 93
# ['worst', 'sarah', 'looking', 'decent', 'boxed']
# XXX
# ['worst', 'sarah', 'looking', 'decent', 'boxed']
# 94
# ['bottle', 'every', 'thing', 'every', 'leaves', 'black', 'residue', 'drink', 'gross', 'smell', 'twisting', 'could', 'would', 'twice', 'amazing']
# XXX
# ['bottle', 'every', 'thing', 'every', 'leaves', 'black', 'residue', 'drink', 'gross', 'smell', 'twisting', 'could', 'would', 'twice', 'amazing']
# 95
# ['bought', 'fifth', 'apple', 'mixed', 'great', 'especially', 'twist', 'fresh', 'lemon']
# XXX
# ['bought', 'fifth', 'apple', 'mixed', 'great', 'especially', 'twist', 'fresh', 'lemon']
# 96
# ['local', 'store', 'purchase', 'another', 'apple', 'flavored', 'product', 'decided', 'purchase', 'apple', 'instead', 'cranberry', 'juice', 'little', 'fizzy', 'seagrams', 'ginger', 'drink', 'purchasing']
# XXX
# ['local', 'store', 'purchase', 'another', 'apple', 'flavored', 'product', 'decided', 'purchase', 'apple', 'instead', 'cranberry', 'juice', 'little', 'fizzy', 'seagrams', 'ginger', 'drink', 'purchasing']
# 97
# ['hesitant', 'apple', 'trying', 'apple', 'whiskeys', 'disappointed', 'smooth', 'light', 'fruity']
# XXX
# ['hesitant', 'apple', 'trying', 'apple', 'whiskeys', 'disappointed', 'smooth', 'light', 'fruity']
# 98
# ['apple', 'little', 'ginger', 'great', 'summer', 'refreshment']
# XXX
# ['apple', 'little', 'ginger', 'great', 'summer', 'refreshment']
# 99
# ['orange', 'slice']
# XXX
# ['orange', 'slice']
# 100
# ['addition', 'makes', 'better']
# XXX
# ['addition', 'makes', 'better']
# 101
# ['drink']
# XXX
# ['drink']
# 102
# ['flavor', 'without', 'powering', 'finish', 'never', 'addition', 'makes', 'betterone', 'favorite', 'silver', 'foods']
# XXX
# ['flavor', 'without', 'powering', 'finish', 'never', 'addition', 'makes', 'betterone', 'favorite', 'silver', 'foods']
# 103
# ['shots']
# XXX
# ['shots']
# 104
# ['hands', 'favorite', 'amazing', 'taste', 'amazing', 'price', 'needed']
# XXX
# ['hands', 'favorite', 'amazing', 'taste', 'amazing', 'price', 'needed']
# 105
# ['drink']
# XXX
# ['drink']
# 106
# ['flavor', 'without', 'powering', 'finish', 'never', 'addition', 'makes', 'betterone', 'favorite', 'silver', 'foods']
# XXX
# ['flavor', 'without', 'powering', 'finish', 'never', 'addition', 'makes', 'betterone', 'favorite', 'silver', 'foods']
# 107
# ['first', 'taste', 'today', 'suprised', 'smooth', 'collection']
# XXX
# ['first', 'taste', 'today', 'suprised', 'smooth', 'collection']
# 108
# ['pizza', 'drinker', 'tasting', 'basil', 'haydens', 'first', 'changed', 'opinion', 'foods', 'enjoy', 'pizza', 'foods']
# XXX
# ['pizza', 'drinker', 'tasting', 'basil', 'haydens', 'first', 'changed', 'opinion', 'foods', 'enjoy', 'pizza', 'foods']
# 109
# ['tasty']
# XXX
# ['tasty']
# 110
# ['basil', 'hayden', 'gateway', 'world', 'burbon', 'since', 'flavor', 'profile', 'standard', 'trying', 'others', 'market', 'always', 'coming', 'first']
# XXX
# ['basil', 'hayden', 'gateway', 'world', 'burbon', 'since', 'flavor', 'profile', 'standard', 'trying', 'others', 'market', 'always', 'coming', 'first']
# 111
# ['outstanding', 'simply', 'outstanding', 'beverage', 'spicy', 'light', 'comforting', 'finish', 'staple', 'rotation', 'never', 'bottle', 'empty', 'without', 'backfilling', 'fresh']
# XXX
# ['outstanding', 'simply', 'outstanding', 'beverage', 'spicy', 'light', 'comforting', 'finish', 'staple', 'rotation', 'never', 'bottle', 'empty', 'without', 'backfilling', 'fresh']
# 112
# ['aficionado', 'favorite', 'patron', 'wanted', 'brand', 'preferred', 'making', 'margaritas', 'hornitos', 'reposado', 'always', 'ranked', 'towards', 'every', 'viewed', 'decided', 'better', 'making', 'pitcher', 'fantastic', 'tasting']
# XXX
# ['aficionado', 'favorite', 'patron', 'wanted', 'brand', 'preferred', 'making', 'margaritas', 'hornitos', 'reposado', 'always', 'ranked', 'towards', 'every', 'viewed', 'decided', 'better', 'making', 'pitcher', 'fantastic', 'tasting']
# 113
# ['perfect', 'sipping', 'chilled']
# XXX
# ['perfect', 'sipping', 'chilled']
# 114
# ['perfect', 'sipping', 'chilled']
# XXX
# ['perfect', 'sipping', 'chilled']
# 115
# ['buddy', 'ordered', 'shots', 'stuff', 'horns', 'frankly', 'comes', 'usually', 'brace', 'rough', 'maybe', 'drinking', 'wrong', 'stuff', 'really', 'lingering', 'aftertaste', 'reasonably', 'priced', 'value', 'youre', 'looking']
# XXX
# ['buddy', 'ordered', 'shots', 'stuff', 'horns', 'frankly', 'comes', 'usually', 'brace', 'rough', 'maybe', 'drinking', 'wrong', 'stuff', 'really', 'lingering', 'aftertaste', 'reasonably', 'priced', 'value', 'youre', 'looking']
# 116
# ['straight']
# XXX
# ['straight']
# 117
# ['cayman', 'margarita', 'really', 'found', 'southern', 'california', 'target', 'northern', 'california', 'stores']
# XXX
# ['cayman', 'margarita', 'really', 'found', 'southern', 'california', 'target', 'northern', 'california', 'stores']
# 118
# ['fruity', 'smooth', 'straight', 'chambord']
# XXX
# ['fruity', 'smooth', 'straight', 'chambord']
# 119
# ['seems', 'missing', 'something', 'better', 'margarita', 'mixes', 'without', 'additives']
# XXX
# ['seems', 'missing', 'something', 'better', 'margarita', 'mixes', 'without', 'additives']
# 120
# ['burger', 'perfect', 'screwdrivers', 'blends', 'juice', 'interesting', 'citrus', 'blend', 'grapefruit', 'juice']
# XXX
# ['burger', 'perfect', 'screwdrivers', 'blends', 'juice', 'interesting', 'citrus', 'blend', 'grapefruit', 'juice']
# 121
# ['disaronno', 'smooth', 'texture', 'flavor', 'lightly', 'sweet', 'decadent', 'rocks', 'little', 'cream']
# XXX
# ['disaronno', 'smooth', 'texture', 'flavor', 'lightly', 'sweet', 'decadent', 'rocks', 'little', 'cream']
# 122
# ['favorite', 'bottle', 'design', 'cheap', 'lager']
# XXX
# ['favorite', 'bottle', 'design', 'cheap', 'lager']
# 123
# ['gluten', 'lower', 'calories', 'refreshing']
# XXX
# ['gluten', 'lower', 'calories', 'refreshing']
# 124
# ['sought', 'memorabilia', 'collectors', 'especially', 'advise', 'locate', 'means', 'still', 'chance']
# XXX
# ['sought', 'memorabilia', 'collectors', 'especially', 'advise', 'locate', 'means', 'still', 'chance']
# 125
# ['arrived', 'perfect', 'condition']
# XXX
# ['arrived', 'perfect', 'condition']
# 126
# ['delicious', 'flavors', 'tastes', 'great', 'store']
# XXX
# ['delicious', 'flavors', 'tastes', 'great', 'store']
# 127
# ['right', 'target', 'sierra', 'nevada', 'torpedo', 'outstanding', 'character', 'subtle', 'hints', 'fruit', 'strong', 'overly', 'bitter', 'aftertaste', 'excellent', 'relax', 'target', 'recently', 'began', 'carrying', 'could', 'enthused']
# XXX
# ['right', 'target', 'sierra', 'nevada', 'torpedo', 'outstanding', 'character', 'subtle', 'hints', 'fruit', 'strong', 'overly', 'bitter', 'aftertaste', 'excellent', 'relax', 'target', 'recently', 'began', 'carrying', 'could', 'enthused']
# 128
# ['money', 'omaha', 'would', 'carry', 'carries']
# XXX
# ['money', 'omaha', 'would', 'carry', 'carries']
# 129
# ['wouldnt', 'drinking']
# XXX
# ['wouldnt', 'drinking']
# 130
# ['yummmmmmyyyyyyyyyyyyyyyy']
# XXX
# ['yummmmmmyyyyyyyyyyyyyyyy']
# 131
# ['prices', 'fantastic', 'better', 'price', 'anywhere', 'please', 'continue', 'price']
# XXX
# ['prices', 'fantastic', 'better', 'price', 'anywhere', 'please', 'continue', 'price']
# 132
# ['never', 'enjoyed', 'stella', 'artois', 'missing']
# XXX
# ['never', 'enjoyed', 'stella', 'artois', 'missing']
# 133
# ['tasty']
# XXX
# ['tasty']
# 134
# ['really', 'enjoy', 'drinks', 'sometimes', 'bloody', 'either', 'clamto', 'juice', 'tastes', 'great']
# XXX
# ['really', 'enjoy', 'drinks', 'sometimes', 'bloody', 'either', 'clamto', 'juice', 'tastes', 'great']
# 135
# ['great', 'product', 'great', 'price']
# XXX
# ['great', 'product', 'great', 'price']
# 136
# ['brand', 'comes', 'close', 'excellent', 'taste']
# XXX
# ['brand', 'comes', 'close', 'excellent', 'taste']
# 137
# ['amber', 'subtle', 'noticeable', 'character', 'great']
# XXX
# ['amber', 'subtle', 'noticeable', 'character', 'great']
# 138
# ['light', 'bodied', 'hopped', 'cascade', 'bright', 'aroma', 'balanced', 'refreshing', 'crisp', 'great', 'cookout', 'beach']
# XXX
# ['light', 'bodied', 'hopped', 'cascade', 'bright', 'aroma', 'balanced', 'refreshing', 'crisp', 'great', 'cookout', 'beach']
# 139
# ['light', 'bodied', 'hopped', 'cascade', 'bright', 'aroma', 'balanced', 'refreshing', 'crisp', 'great', 'cookout', 'beach']
# XXX
# ['light', 'bodied', 'hopped', 'cascade', 'bright', 'aroma', 'balanced', 'refreshing', 'crisp', 'great', 'cookout', 'beach']
# 140
# ['refreshing', 'grapefruit', 'flavor', 'people', 'dislike', 'seltzer', 'water', 'poured']
# XXX
# ['refreshing', 'grapefruit', 'flavor', 'people', 'dislike', 'seltzer', 'water', 'poured']
# 141
# ['refreshing', 'loveit']
# XXX
# ['refreshing', 'loveit']
# 142
# ['sweetand', 'taste', 'sparkling', 'water', 'benefit', 'alcohol']
# XXX
# ['sweetand', 'taste', 'sparkling', 'water', 'benefit', 'alcohol']
# 143
# ['obsessed', 'drinkhowever', 'every', 'target', 'lately']
# XXX
# ['obsessed', 'drinkhowever', 'every', 'target', 'lately']
# 144
# ['delicious', 'quite', 'sweet', 'cream', 'perfect', 'absolutely']
# XXX
# ['delicious', 'quite', 'sweet', 'cream', 'perfect', 'absolutely']
# 145
# ['agave', 'light', 'golden', 'syrup', 'sauza', 'perfect', 'drink']
# XXX
# ['agave', 'light', 'golden', 'syrup', 'sauza', 'perfect', 'drink']
# 146
# ['agave', 'light', 'golden', 'syrup', 'sauza', 'perfect', 'drink']
# XXX
# ['agave', 'light', 'golden', 'syrup', 'sauza', 'perfect', 'drink']
# 147
# ['brand', 'margarita', 'different', 'kinds']
# XXX
# ['brand', 'margarita', 'different', 'kinds']
# 148
# ['product', 'flavor', 'bland', 'spicy']
# XXX
# ['product', 'flavor', 'bland', 'spicy']
# 149
# ['enjoyed', 'flavor']
# XXX
# ['enjoyed', 'flavor']
# 150
# ['tasty']
# XXX
# ['tasty']
# 151
# ['loved', 'spicy', 'enough', 'better', 'original']
# XXX
# ['loved', 'spicy', 'enough', 'better', 'original']
# 152
# ['bloody']
# XXX
# ['bloody']
# 153
# ['think', 'putting', 'sucrose', 'would', 'better', 'sweetness']
# XXX
# ['think', 'putting', 'sucrose', 'would', 'better', 'sweetness']
# 154
# ['husband', 'loves', 'flavor']
# XXX
# ['husband', 'loves', 'flavor']
# 155
# ['tastes', 'delicious', 'without', 'burger']
# XXX
# ['tastes', 'delicious', 'without', 'burger']
# 156
# ['sence', 'snappy']
# XXX
# ['sence', 'snappy']
# 157
# ['tasty']
# XXX
# ['tasty']
# 158
# ['extra']
# XXX
# ['extra']
# 159
# ['drinking', 'quite', 'awhile', 'better']
# XXX
# ['drinking', 'quite', 'awhile', 'better']
# 160
# ['review', 'collected', 'promotion']
# XXX
# ['review', 'collected', 'promotion']
# 161
# ['delicious', 'would', 'highly', 'recommend']
# XXX
# ['delicious', 'would', 'highly', 'recommend']
# 162
# ['cooking', 'enough']
# XXX
# ['cooking', 'enough']
# 163
# ['shipped', 'without', 'spillage', 'product', 'place', 'v8being', 'louisiana', 'spicy']
# XXX
# ['shipped', 'without', 'spillage', 'product', 'place', 'v8being', 'louisiana', 'spicy']
# 164
# ['excellenti', 'every']
# XXX
# ['excellenti', 'every']
# 165
# ['bottle', 'bloody', 'store', 'carry', 'large', 'bottle', 'usually', 'original', 'flavor', 'spicy', 'compared', 'places']
# XXX
# ['bottle', 'bloody', 'store', 'carry', 'large', 'bottle', 'usually', 'original', 'flavor', 'spicy', 'compared', 'places']
# 166
# ['looking', 'spicy', 'bloody', 'great']
# XXX
# ['looking', 'spicy', 'bloody', 'great']
# 167
# ['tried', 'several', 'different', 'bloody', 'mixes', 'found']
# XXX
# ['tried', 'several', 'different', 'bloody', 'mixes', 'found']
# 168
# ['friend', 'product', 'tried', 'loved', 'sooner']
# XXX
# ['friend', 'product', 'tried', 'loved', 'sooner']
# 169
# ['excellent', 'thick', 'right', 'amount', 'always', 'ordered', 'travelled']
# XXX
# ['excellent', 'thick', 'right', 'amount', 'always', 'ordered', 'travelled']
# 170
# ['really', 'right', 'amputated', 'spice', 'spicey']
# XXX
# ['really', 'right', 'amputated', 'spice', 'spicey']
# 171
# ['spicy']
# XXX
# ['spicy']
# 172
# ['flavor']
# XXX
# ['flavor']
# 173
# ['drinking', 'riunite', 'yearsits', 'great', 'partying', 'friends', 'family', 'relaxing', 'buying', 'holidays', 'gumbo']
# XXX
# ['drinking', 'riunite', 'yearsits', 'great', 'partying', 'friends', 'family', 'relaxing', 'buying', 'holidays', 'gumbo']
# 174
# ['taste', 'really', 'flavor']
# XXX
# ['taste', 'really', 'flavor']
# 175
# ['wonderful', 'price', 'carried']
# XXX
# ['wonderful', 'price', 'carried']
# 176
# ['amazing', 'sweet', 'bitter', 'great', 'inexpensive']
# XXX
# ['amazing', 'sweet', 'bitter', 'great', 'inexpensive']
# 177
# ['drink', 'white', 'needed', 'budget', 'bottle', 'dollar', 'bottles', 'beats', 'pretty', 'impress', 'anyone', 'mondaythursday', 'budget', 'drinking']
# XXX
# ['drink', 'white', 'needed', 'budget', 'bottle', 'dollar', 'bottles', 'beats', 'pretty', 'impress', 'anyone', 'mondaythursday', 'budget', 'drinking']
# 178
# ['really', 'smooth', 'taste', 'cough', 'syrup', 'black', 'cherry', 'vanilla', 'waste', 'money', 'green', 'apple', 'blood', 'orange']
# XXX
# ['really', 'smooth', 'taste', 'cough', 'syrup', 'black', 'cherry', 'vanilla', 'waste', 'money', 'green', 'apple', 'blood', 'orange']
# 179
# ['really', 'smooth', 'taste', 'cough', 'syrup', 'black', 'cherry', 'vanilla', 'waste', 'money', 'green', 'apple', 'blood', 'orange']
# XXX
# ['really', 'smooth', 'taste', 'cough', 'syrup', 'black', 'cherry', 'vanilla', 'waste', 'money', 'green', 'apple', 'blood', 'orange']
# 180
# ['taste', 'drink']
# XXX
# ['taste', 'drink']
# 181
# ['flavored', 'burger', 'market', 'drink', 'water', 'flavor', 'crisp', 'sweet', 'thick']
# XXX
# ['flavored', 'burger', 'market', 'drink', 'water', 'flavor', 'crisp', 'sweet', 'thick']
# 182
# ['great', 'rocking', 'today', 'disappointed']
# XXX
# ['great', 'rocking', 'today', 'disappointed']
# 183
# ['chata', 'great', 'mixed', 'fireball', 'caramel', 'burger']
# XXX
# ['chata', 'great', 'mixed', 'fireball', 'caramel', 'burger']
# 184
# ['drink', 'choice', 'really', 'enjoy', 'alone']
# XXX
# ['drink', 'choice', 'really', 'enjoy', 'alone']
# 185
# ['makes', 'orange', 'jello', 'taste', 'creamsicle', 'strawberry', 'taste', 'strawberries', 'cream', 'lemon', 'taste', 'lemon', 'meringuei', 'could', 'onget', 'today']
# XXX
# ['makes', 'orange', 'jello', 'taste', 'creamsicle', 'strawberry', 'taste', 'strawberries', 'cream', 'lemon', 'taste', 'lemon', 'meringuei', 'could', 'onget', 'today']
# 186
# ['pinnacle', 'making', 'martinis', 'family', 'years', 'father', 'discovered', 'years', 'someone', 'burger', 'south', 'winter', 'reasonable', 'price', 'youll']
# XXX
# ['pinnacle', 'making', 'martinis', 'family', 'years', 'father', 'discovered', 'years', 'someone', 'burger', 'south', 'winter', 'reasonable', 'price', 'youll']
# 187
# ['whipped', 'creme', 'flavored', 'burger', 'fabulous', 'freezer', 'snifter', 'something', 'smooth', 'dinner', 'night']
# XXX
# ['whipped', 'creme', 'flavored', 'burger', 'fabulous', 'freezer', 'snifter', 'something', 'smooth', 'dinner', 'night']
# 188
# ['everything', 'great', 'product', 'cheap', 'price', 'perfect', 'taste', 'mixing', 'flavor', 'makes', 'delicious']
# XXX
# ['everything', 'great', 'product', 'cheap', 'price', 'perfect', 'taste', 'mixing', 'flavor', 'makes', 'delicious']
# 189
# ['burger', 'drinking', 'burger', 'years', 'favorite', 'burger', 'drink', 'regularly', 'usually', 'grape', 'juice', 'orange', 'juice', 'daiquiris', 'frozen', 'concoctions']
# XXX
# ['burger', 'drinking', 'burger', 'years', 'favorite', 'burger', 'drink', 'regularly', 'usually', 'grape', 'juice', 'orange', 'juice', 'daiquiris', 'frozen', 'concoctions']
# 190
# ['titos', 'burger', 'drink', 'years']
# XXX
# ['titos', 'burger', 'drink', 'years']
# 191
# ['drink', 'choice', 'really', 'enjoy', 'alone']
# XXX
# ['drink', 'choice', 'really', 'enjoy', 'alone']
# 192
# ['pinnacle', 'making', 'martinis', 'family', 'years', 'father', 'discovered', 'years', 'someone', 'burger', 'south', 'winter', 'reasonable', 'price', 'youll']
# XXX
# ['pinnacle', 'making', 'martinis', 'family', 'years', 'father', 'discovered', 'years', 'someone', 'burger', 'south', 'winter', 'reasonable', 'price', 'youll']
# 193
# ['whipped', 'creme', 'flavored', 'burger', 'fabulous', 'freezer', 'snifter', 'something', 'smooth', 'dinner', 'night']
# XXX
# ['whipped', 'creme', 'flavored', 'burger', 'fabulous', 'freezer', 'snifter', 'something', 'smooth', 'dinner', 'night']
# 194
# ['burger', 'drinking', 'burger', 'years', 'favorite', 'burger', 'drink', 'regularly', 'usually', 'grape', 'juice', 'orange', 'juice', 'daiquiris', 'frozen', 'concoctions']
# XXX
# ['burger', 'drinking', 'burger', 'years', 'favorite', 'burger', 'drink', 'regularly', 'usually', 'grape', 'juice', 'orange', 'juice', 'daiquiris', 'frozen', 'concoctions']
# 195
# ['chardonnay', 'pairs', 'great', 'types', 'meals', 'seems', 'appease', 'drinkers', 'choice', 'large', 'gatherings', 'great', 'value', 'guests', 'happy', 'quality']
# XXX
# ['chardonnay', 'pairs', 'great', 'types', 'meals', 'seems', 'appease', 'drinkers', 'choice', 'large', 'gatherings', 'great', 'value', 'guests', 'happy', 'quality']
# 196
# ['price', 'selection', 'served', 'foods', 'super', 'gatherings', 'recently', 'thanksgiving', 'celebration', 'everyone', 'enjoyed', 'foods', 'asked', 'thought', 'couldnt', 'believe', 'value', 'belle', 'foods']
# XXX
# ['price', 'selection', 'served', 'foods', 'super', 'gatherings', 'recently', 'thanksgiving', 'celebration', 'everyone', 'enjoyed', 'foods', 'asked', 'thought', 'couldnt', 'believe', 'value', 'belle', 'foods']
# 197
# ['manhattan', 'almost', 'everyday', 'bought', 'although', 'decent', 'necessary', 'spend', 'money', 'quality', 'vermouth', 'course', 'afford']
# XXX
# ['manhattan', 'almost', 'everyday', 'bought', 'although', 'decent', 'necessary', 'spend', 'money', 'quality', 'vermouth', 'course', 'afford']
# 198
# ['great', 'product', 'prefect', 'parties', 'graduation', 'summer']
# XXX
# ['great', 'product', 'prefect', 'parties', 'graduation', 'summer']
# 199
# ['cocktail', 'artist', 'robert', 'porter', 'first', 'thank', 'taking', 'review', 'cocktail', 'artist', 'premium', 'manhattan', 'totally', 'humbled', 'passionate', 'bringing', 'remarkable', 'product', 'guess', 'making', 'exceptional', 'manhattan', 'parts', 'whiskey', 'manhattan', 'enjoyyes', 'create', 'unique', 'product', 'natural', 'ingredients', 'sugar', 'smooth', 'balanced', 'cocktail', 'doesnt', 'artificial', 'flavors', 'aftertaste', 'manhattan', 'cocktail', 'artist', 'essential', 'ingredients', 'easily', 'create', 'variety', 'amazing', 'drinks', 'cocktail', 'artist', 'lemon', 'juice', 'perfect', 'whiskey', 'syrup', 'amazing', 'julip', 'whiskey', 'spirits', 'manhattan', 'premium', 'juice', 'margarita', 'stormy', 'using', 'manhattan', 'another', 'favorite', 'nigroni', 'manhattan', 'campari', 'orange', 'twist', 'exparament', 'create', 'glass', 'canvas', 'robert']
# XXX
# ['cocktail', 'artist', 'robert', 'porter', 'first', 'thank', 'taking', 'review', 'cocktail', 'artist', 'premium', 'manhattan', 'totally', 'humbled', 'passionate', 'bringing', 'remarkable', 'product', 'guess', 'making', 'exceptional', 'manhattan', 'parts', 'whiskey', 'manhattan', 'enjoyyes', 'create', 'unique', 'product', 'natural', 'ingredients', 'sugar', 'smooth', 'balanced', 'cocktail', 'doesnt', 'artificial', 'flavors', 'aftertaste', 'manhattan', 'cocktail', 'artist', 'essential', 'ingredients', 'easily', 'create', 'variety', 'amazing', 'drinks', 'cocktail', 'artist', 'lemon', 'juice', 'perfect', 'whiskey', 'syrup', 'amazing', 'julip', 'whiskey', 'spirits', 'manhattan', 'premium', 'juice', 'margarita', 'stormy', 'using', 'manhattan', 'another', 'favorite', 'nigroni', 'manhattan', 'campari', 'orange', 'twist', 'exparament', 'create', 'glass', 'canvas', 'robert']
# 200
# ['omglove', 'cocktail', 'everyone']
# XXX
# ['omglove', 'cocktail', 'everyone']
# 201
# ['although', 'necessary', 'describe', 'angels', 'heaven', 'squeeze', 'droplets', 'nirvana', 'bottle', 'across', 'country', 'retailers', 'brand', 'recipe', 'expressing', 'everyone', 'bitter', 'powerful', 'concoction', 'ecstasy', 'unbelievably', 'awesome', 'likely', 'raging', 'alcoholic', 'passed', 'gutter', 'occasionally', 'coming', 'surface', 'scream', 'monkeys', 'degenerate', 'courtesans', 'frolic', 'bodily', 'fluids', 'streaming', 'freaking', 'folks', 'cases', 'snort', 'drink', 'shoot', 'whatever', 'youll', 'leaving', 'another', 'depraved', 'review', 'hopefully', 'three', 'times', 'twisted', 'speed', 'speed']
# XXX
# ['although', 'necessary', 'describe', 'angels', 'heaven', 'squeeze', 'droplets', 'nirvana', 'bottle', 'across', 'country', 'retailers', 'brand', 'recipe', 'expressing', 'everyone', 'bitter', 'powerful', 'concoction', 'ecstasy', 'unbelievably', 'awesome', 'likely', 'raging', 'alcoholic', 'passed', 'gutter', 'occasionally', 'coming', 'surface', 'scream', 'monkeys', 'degenerate', 'courtesans', 'frolic', 'bodily', 'fluids', 'streaming', 'freaking', 'folks', 'cases', 'snort', 'drink', 'shoot', 'whatever', 'youll', 'leaving', 'another', 'depraved', 'review', 'hopefully', 'three', 'times', 'twisted', 'speed', 'speed']
# 202
# ['finding', 'hosting', 'impromptu', 'party', 'friend', 'scrambled', 'knowing', 'beverage', 'knowledge', 'basic', 'limited', 'essentially', 'liquorsoda', 'would', 'several', 'liquor', 'including', 'would', 'sizeup', 'novice', 'bartending', 'abilities', 'enter', 'cocktail', 'artist', 'essential', 'ingredients', 'premium', 'manhattan', 'making', 'preshindig', 'walmart', 'circled', 'aisles', 'looking', 'something', 'could', 'across', 'bottle', 'liquid', 'magic', 'allowed', 'craft', 'topnotch', 'manhattans', 'still', 'asked', 'party', 'patrons', 'secret', 'recipe', 'figure', 'instant', 'bartender', 'credibility', 'soire', 'lifesaver']
# XXX
# ['finding', 'hosting', 'impromptu', 'party', 'friend', 'scrambled', 'knowing', 'beverage', 'knowledge', 'basic', 'limited', 'essentially', 'liquorsoda', 'would', 'several', 'liquor', 'including', 'would', 'sizeup', 'novice', 'bartending', 'abilities', 'enter', 'cocktail', 'artist', 'essential', 'ingredients', 'premium', 'manhattan', 'making', 'preshindig', 'walmart', 'circled', 'aisles', 'looking', 'something', 'could', 'across', 'bottle', 'liquid', 'magic', 'allowed', 'craft', 'topnotch', 'manhattans', 'still', 'asked', 'party', 'patrons', 'secret', 'recipe', 'figure', 'instant', 'bartender', 'credibility', 'soire', 'lifesaver']
# 203
# ['bought', 'minute', 'dinner', 'party', 'pleasantly', 'surprised', 'tried', 'bulleit', 'rittenhouse', 'great', 'citrusyness', 'brings', 'flavors', 'together', 'quite', 'nicely', 'wasnt', 'sweet', 'syrupy', 'artificial', 'tasting', 'loved', 'product', 'definitely', 'making', 'staple', 'barcant', 'sample', 'products']
# XXX
# ['bought', 'minute', 'dinner', 'party', 'pleasantly', 'surprised', 'tried', 'bulleit', 'rittenhouse', 'great', 'citrusyness', 'brings', 'flavors', 'together', 'quite', 'nicely', 'wasnt', 'sweet', 'syrupy', 'artificial', 'tasting', 'loved', 'product', 'definitely', 'making', 'staple', 'barcant', 'sample', 'products']
# 204
# ['easiest', 'manhatten', 'great', 'cocktail', 'party', 'always', 'sometimes', 'fancy', 'drink']
# XXX
# ['easiest', 'manhatten', 'great', 'cocktail', 'party', 'always', 'sometimes', 'fancy', 'drink']
# 205
# ['cocktail', 'product', 'husband', 'career', 'bartender', 'changed', 'staple', 'smooth', 'light', 'makes', 'impossible']
# XXX
# ['cocktail', 'product', 'husband', 'career', 'bartender', 'changed', 'staple', 'smooth', 'light', 'makes', 'impossible']
# 206
# ['impressed', 'mannhattan', 'represented', 'robert', 'porter', 'natural', 'ingredients', 'laden', 'chemicals', 'prefer', 'drinks', 'taste', 'fresh', 'balanced', 'lovely', 'complement', 'whiskey', 'choice', 'highly', 'recommend']
# XXX
# ['impressed', 'mannhattan', 'represented', 'robert', 'porter', 'natural', 'ingredients', 'laden', 'chemicals', 'prefer', 'drinks', 'taste', 'fresh', 'balanced', 'lovely', 'complement', 'whiskey', 'choice', 'highly', 'recommend']
# 207
# ['amazing', 'shocked', 'smooth', 'tasty', 'usually', 'cocktail', 'mixes', 'friend', 'recommended', 'defiantly', 'staple', 'parties']
# XXX
# ['amazing', 'shocked', 'smooth', 'tasty', 'usually', 'cocktail', 'mixes', 'friend', 'recommended', 'defiantly', 'staple', 'parties']
# 208
# ['never', 'thought', 'buying', 'tasty', 'delicious', 'favorite', 'whiskey', 'robert', 'porter', 'super', 'manhattan', 'smooth', 'tastes', 'amazing', 'highly', 'recommended']
# XXX
# ['never', 'thought', 'buying', 'tasty', 'delicious', 'favorite', 'whiskey', 'robert', 'porter', 'super', 'manhattan', 'smooth', 'tastes', 'amazing', 'highly', 'recommended']
# 209
# ['wasnt', 'first', 'inexpensivebut', 'thought', 'exceeded', 'expectations', 'delicious', 'smooth', 'super', 'impressed', 'doesnt', 'bottle', 'cutejust', 'sayin']
# XXX
# ['wasnt', 'first', 'inexpensivebut', 'thought', 'exceeded', 'expectations', 'delicious', 'smooth', 'super', 'impressed', 'doesnt', 'bottle', 'cutejust', 'sayin']
# 210
# ['superb', 'drink', 'getting', 'dressed', 'upscale', 'downtown', 'invite', 'friend', 'share', 'cocktail', 'elegant', 'drink', 'sophisticated', 'palate', 'cocktail', 'staple']
# XXX
# ['superb', 'drink', 'getting', 'dressed', 'upscale', 'downtown', 'invite', 'friend', 'share', 'cocktail', 'elegant', 'drink', 'sophisticated', 'palate', 'cocktail', 'staple']
# 211
# ['personally', 'mixes', 'bought', 'entertaining', 'friends', 'night', 'extremely', 'impressed', 'smooth', 'balanced', 'everyone', 'loved', 'manhattans', 'whiskey', 'choice', 'artificial', 'flavors', 'fructose', 'syrups', 'either', 'sugar', 'honestly', 'probably', 'safer', 'using', 'liqueurs', 'market', 'bartender', 'telling', 'product']
# XXX
# ['personally', 'mixes', 'bought', 'entertaining', 'friends', 'night', 'extremely', 'impressed', 'smooth', 'balanced', 'everyone', 'loved', 'manhattans', 'whiskey', 'choice', 'artificial', 'flavors', 'fructose', 'syrups', 'either', 'sugar', 'honestly', 'probably', 'safer', 'using', 'liqueurs', 'market', 'bartender', 'telling', 'product']
# 212
# ['manhattan', 'mixer', 'weekend', 'party', 'absolute', 'cocktails', 'delicious', 'simple', 'conversational', 'pieces', 'party']
# XXX
# ['manhattan', 'mixer', 'weekend', 'party', 'absolute', 'cocktails', 'delicious', 'simple', 'conversational', 'pieces', 'party']
# 213
# ['great', 'stuff', 'wasnt', 'expect', 'trying', 'first', 'tried', 'manhattan', 'easier', 'drink', 'delicious', 'smooth', 'wonderful', 'palette', 'going', 'friends', 'great', 'stuff', 'please', 'stock']
# XXX
# ['great', 'stuff', 'wasnt', 'expect', 'trying', 'first', 'tried', 'manhattan', 'easier', 'drink', 'delicious', 'smooth', 'wonderful', 'palette', 'going', 'friends', 'great', 'stuff', 'please', 'stock']
# 214
# ['bodied', 'delicious', 'together', 'needing', 'manhattan']
# XXX
# ['bodied', 'delicious', 'together', 'needing', 'manhattan']
# 215
# ['manhattan', 'although', 'rarely', 'however', 'decided', 'price', 'couldnt', 'smooth', 'taste', 'authentic', 'manhattan', 'follow', 'directions', 'bottle', 'simple', 'great', 'tasting', 'mixer', 'bottle', 'price']
# XXX
# ['manhattan', 'although', 'rarely', 'however', 'decided', 'price', 'couldnt', 'smooth', 'taste', 'authentic', 'manhattan', 'follow', 'directions', 'bottle', 'simple', 'great', 'tasting', 'mixer', 'bottle', 'price']
# 216
# ['manhattan', 'perfect', 'tasty', 'smooth', 'party', 'first', 'tried', 'drink', 'purchased', 'party', 'coming', 'share', 'think', 'people']
# XXX
# ['manhattan', 'perfect', 'tasty', 'smooth', 'party', 'first', 'tried', 'drink', 'purchased', 'party', 'coming', 'share', 'think', 'people']
# 217
# ['great', 'tasting', 'proof', 'served', 'stylish', 'bottle']
# XXX
# ['great', 'tasting', 'proof', 'served', 'stylish', 'bottle']
# 218
# ['delicious', 'actually', 'perfect', 'tasting', 'smooth', 'manhattan', 'great', 'product']
# XXX
# ['delicious', 'actually', 'perfect', 'tasting', 'smooth', 'manhattan', 'great', 'product']
# 219
# ['party', 'night', 'fantastic', 'whoever', 'together', 'knows', 'stuff', 'highly', 'recommended']
# XXX
# ['party', 'night', 'fantastic', 'whoever', 'together', 'knows', 'stuff', 'highly', 'recommended']
# 220
# ['amazing', 'product', 'absolutely']
# XXX
# ['amazing', 'product', 'absolutely']
# 221
# ...
# 1185
# ['consider', 'lover', 'decided', 'finally', 'order', 'mixed', 'whites', 'trying', 'variety', 'regret', 'decision', 'horrible', 'arent', 'either', 'arent', 'foods', 'serve', 'anyone', 'drink', 'alone', 'purchase', 'sweet', 'doubt', 'taste', 'described', 'sweet', 'chardonnay', 'strangest', 'tasting', 'chardonnay', 'tasted', 'described', 'guess', 'chardonnay', 'pinot', 'expert', 'repeatedly', 'mispronounced', 'bland', 'cabernet', 'sauvingnon', 'supposed', 'bunch', 'private', 'reserve', 'turned', 'disappointing', 'foods', 'touted', 'retail', 'value', 'bottle', 'taste', 'bottle', 'exactly', 'works', 'something', 'sounds', 'probably', 'lessons', 'learned']
# XXX
# ['consider', 'lover', 'decided', 'finally', 'order', 'mixed', 'whites', 'trying', 'variety', 'regret', 'decision', 'horrible', 'arent', 'either', 'arent', 'foods', 'serve', 'anyone', 'drink', 'alone', 'purchase', 'sweet', 'doubt', 'taste', 'described', 'sweet', 'chardonnay', 'strangest', 'tasting', 'chardonnay', 'tasted', 'described', 'guess', 'chardonnay', 'pinot', 'expert', 'repeatedly', 'mispronounced', 'bland', 'cabernet', 'sauvingnon', 'supposed', 'bunch', 'private', 'reserve', 'turned', 'disappointing', 'foods', 'touted', 'retail', 'value', 'bottle', 'taste', 'bottle', 'exactly', 'works', 'something', 'sounds', 'probably', 'lessons', 'learned']
# 1186
# ['variety', 'offered', 'sweet', 'pinot', 'average', 'nothing', 'special', 'outstanding', 'wouldnäôt', 'chardonnay', 'awfuläî', 'maybe', 'bottle', 'opened', 'immediately', 'smelled', 'spoiled', 'tasted', 'wound', 'pouring', 'drain', 'hoping', 'bottles', 'arenäôt', 'rotten', 'tried', 'itäôs', 'favorite', 'disappointedäîhoping', 'weäôll', 'least', 'sorry', 'iäôll']
# XXX
# ['variety', 'offered', 'sweet', 'pinot', 'average', 'nothing', 'special', 'outstanding', 'wouldnäôt', 'chardonnay', 'awfuläî', 'maybe', 'bottle', 'opened', 'immediately', 'smelled', 'spoiled', 'tasted', 'wound', 'pouring', 'drain', 'hoping', 'bottles', 'arenäôt', 'rotten', 'tried', 'itäôs', 'favorite', 'disappointedäîhoping', 'weäôll', 'least', 'sorry', 'iäôll']
# 1187
# ['variety', 'offered', 'sweet', 'pinot', 'average', 'nothing', 'special', 'outstanding', 'wouldnt', 'chardonnay', 'awful', 'maybe', 'bottle', 'opened', 'immediately', 'smelled', 'spoiled', 'tasted', 'wound', 'pouring', 'drain', 'hoping', 'bottles', 'arent', 'rotten', 'tried', 'favorite', 'disappointedhoping', 'least', 'sorry']
# XXX
# ['variety', 'offered', 'sweet', 'pinot', 'average', 'nothing', 'special', 'outstanding', 'wouldnt', 'chardonnay', 'awful', 'maybe', 'bottle', 'opened', 'immediately', 'smelled', 'spoiled', 'tasted', 'wound', 'pouring', 'drain', 'hoping', 'bottles', 'arent', 'rotten', 'tried', 'favorite', 'disappointedhoping', 'least', 'sorry']
# 1188
# ['tried', 'acceptable', 'wanted', 'glass', 'pinot', 'young', 'drink', 'refreshing', 'tried', 'chardonnay', 'group', 'foods', 'worked', 'price', 'grocery', 'store', 'delivered', 'house', 'variety', 'foods', 'normally', 'would', 'purchase', 'marked', 'would', 'recommend', 'everyones', 'palate', 'different', 'usually']
# XXX
# ['tried', 'acceptable', 'wanted', 'glass', 'pinot', 'young', 'drink', 'refreshing', 'tried', 'chardonnay', 'group', 'foods', 'worked', 'price', 'grocery', 'store', 'delivered', 'house', 'variety', 'foods', 'normally', 'would', 'purchase', 'marked', 'would', 'recommend', 'everyones', 'palate', 'different', 'usually']
# 1189
# ['waiting', 'bundle', 'presentation', 'indicated', 'bearing', 'sweet', 'middle', 'therefore', 'enjoy', 'along', 'delicious', 'favorite', 'chardonnay', 'delicious', 'cheese', 'david', 'everything', 'better', 'cheese', 'delivery', 'could', 'preorder', 'smooth', 'everything', 'presentation', 'david', 'hosts', 'enjoying', 'bundle', 'thank', 'vintage', 'estates', 'sincerely']
# XXX
# ['waiting', 'bundle', 'presentation', 'indicated', 'bearing', 'sweet', 'middle', 'therefore', 'enjoy', 'along', 'delicious', 'favorite', 'chardonnay', 'delicious', 'cheese', 'david', 'everything', 'better', 'cheese', 'delivery', 'could', 'preorder', 'smooth', 'everything', 'presentation', 'david', 'hosts', 'enjoying', 'bundle', 'thank', 'vintage', 'estates', 'sincerely']
# 1190
# ['still', 'sampling', 'favorite', 'chardonnay', 'change']
# XXX
# ['still', 'sampling', 'favorite', 'chardonnay', 'change']
# 1191
# ['received', 'collection', 'opened', 'tasty', 'overly', 'sweet', 'concern', 'light', 'fruity', 'taste', 'pairs', 'cheeses', 'havent', 'tasted', 'others', 'great', 'quantity', 'receive', 'continue', 'update', 'others']
# XXX
# ['received', 'collection', 'opened', 'tasty', 'overly', 'sweet', 'concern', 'light', 'fruity', 'taste', 'pairs', 'cheeses', 'havent', 'tasted', 'others', 'great', 'quantity', 'receive', 'continue', 'update', 'others']
# 1192
# ['could', 'positive', 'review', 'timefound', 'lacking', 'greatly', 'aroma', 'unpleasant', 'finishusually', 'pleased', 'overall', 'foods', 'definite']
# XXX
# ['could', 'positive', 'review', 'timefound', 'lacking', 'greatly', 'aroma', 'unpleasant', 'finishusually', 'pleased', 'overall', 'foods', 'definite']
# 1193
# ['happy', 'lincluded', 'instead', 'sweet', 'zinfandel', 'unfortunately', 'sweeter', 'zinfandel', 'disappointed']
# XXX
# ['happy', 'lincluded', 'instead', 'sweet', 'zinfandel', 'unfortunately', 'sweeter', 'zinfandel', 'disappointed']
# 1194
# ['great', 'opinion', 'taste', 'subjective', 'opinion', 'foods', 'harsh', 'smooth', 'taste', 'hosts', 'claimed', 'drink', 'hoped', 'cancelled', 'delivery', 'bought', 'mixed', 'tried']
# XXX
# ['great', 'opinion', 'taste', 'subjective', 'opinion', 'foods', 'harsh', 'smooth', 'taste', 'hosts', 'claimed', 'drink', 'hoped', 'cancelled', 'delivery', 'bought', 'mixed', 'tried']
# 1195
# ['brought', 'opened', 'advertised', 'sweet', 'thats', 'reason', 'drink', 'roses', 'either', 'sweet', 'however', 'mildly', 'sweet', 'smooth', 'getting', 'ready', 'would', 'serve', 'group', 'personal', 'connoisseur']
# XXX
# ['brought', 'opened', 'advertised', 'sweet', 'thats', 'reason', 'drink', 'roses', 'either', 'sweet', 'however', 'mildly', 'sweet', 'smooth', 'getting', 'ready', 'would', 'serve', 'group', 'personal', 'connoisseur']
# 1196
# ['realize', 'inexpensive', 'bottle', 'tasteless']
# XXX
# ['realize', 'inexpensive', 'bottle', 'tasteless']
# 1197
# ['based', 'reading', 'reviews', 'considered', 'canceling', 'order', 'received', 'first', 'shipment', 'really', 'enjoying', 'cabernet', 'sauvignon', 'signed', 'autoship']
# XXX
# ['based', 'reading', 'reviews', 'considered', 'canceling', 'order', 'received', 'first', 'shipment', 'really', 'enjoying', 'cabernet', 'sauvignon', 'signed', 'autoship']
# 1198
# ['chards', 'light', 'delicious', 'ordered', 'another', 'automated', 'ordering', 'changed', 'every', 'disappointed']
# XXX
# ['chards', 'light', 'delicious', 'ordered', 'another', 'automated', 'ordering', 'changed', 'every', 'disappointed']
# 1199
# ['expert', 'novice', 'delicious', 'ordered', 'autoship']
# XXX
# ['expert', 'novice', 'delicious', 'ordered', 'autoship']
# 1200
# ['bought', 'sweetit', 'turned', 'tasteless', 'really', 'nastyalso', 'herei', 'tired', 'takes', 'packages', 'arrive']
# XXX
# ['bought', 'sweetit', 'turned', 'tasteless', 'really', 'nastyalso', 'herei', 'tired', 'takes', 'packages', 'arrive']
# 1201
# ['purchased', 'various', 'cheaper', 'brands', 'liked', 'seemed', 'mellow', 'mention', 'presentation', 'deliver', 'found', 'tracking', 'delivery', 'local', 'state', 'store', 'regular', 'brand']
# XXX
# ['purchased', 'various', 'cheaper', 'brands', 'liked', 'seemed', 'mellow', 'mention', 'presentation', 'deliver', 'found', 'tracking', 'delivery', 'local', 'state', 'store', 'regular', 'brand']
# 1202
# ['david', 'awesome', 'glass', 'iôøωôøωôøωm', 'going']
# XXX
# ['david', 'awesome', 'glass', 'iôøωôøωôøωm', 'going']
# 1203
# ['sweet', 'mellow', 'drinker', 'drank', 'going', 'order', 'ordered']
# XXX
# ['sweet', 'mellow', 'drinker', 'drank', 'going', 'order', 'ordered']
# 1204
# ['purchased', 'bottle', 'harvest', 'collection', 'several', 'weeks', 'insane', 'price', 'tried', 'pinot', 'night', 'fantastic', 'looking', 'forward', 'giving', 'gifts', 'upcoming', 'holiday', 'season', 'wrong', 'foods', 'great', 'everyone']
# XXX
# ['purchased', 'bottle', 'harvest', 'collection', 'several', 'weeks', 'insane', 'price', 'tried', 'pinot', 'night', 'fantastic', 'looking', 'forward', 'giving', 'gifts', 'upcoming', 'holiday', 'season', 'wrong', 'foods', 'great', 'everyone']
# 1205
# ['ointment', 'works', 'downfall', 'metal', 'applicator', 'plastic', 'similar', 'products', 'would', 'stars']
# XXX
# ['ointment', 'works', 'downfall', 'metal', 'applicator', 'plastic', 'similar', 'products', 'would', 'stars']
# 1206
# ['ointment', 'paralyzed', 'doesnt', 'produce', 'tears', 'ointment', 'everyday', 'works', 'stinging', 'instant', 'relief']
# XXX
# ['ointment', 'paralyzed', 'doesnt', 'produce', 'tears', 'ointment', 'everyday', 'works', 'stinging', 'instant', 'relief']
# 1207
# ['sparkling', 'brands', 'sweet', 'aging', 'longer', 'sweet', 'stufd', 'medium', 'strong', 'bubbles', 'bubbles', 'alcohol', 'content', 'offers', 'fairly', 'quickly', 'ecstatic', 'found', 'brand', 'target', 'carries']
# XXX
# ['sparkling', 'brands', 'sweet', 'aging', 'longer', 'sweet', 'stufd', 'medium', 'strong', 'bubbles', 'bubbles', 'alcohol', 'content', 'offers', 'fairly', 'quickly', 'ecstatic', 'found', 'brand', 'target', 'carries']
# 1208
# ['wonderful', 'taste', 'divine']
# XXX
# ['wonderful', 'taste', 'divine']
# 1209
# ['wonderful', 'taste', 'divine']
# XXX
# ['wonderful', 'taste', 'divine']
# 1210
# ['sweet', 'perfect', 'summer']
# XXX
# ['sweet', 'perfect', 'summer']
# 1211
# ['perfect', 'dirty', 'martini', 'saltiness']
# XXX
# ['perfect', 'dirty', 'martini', 'saltiness']
# 1212
# ['dirty', 'martini', 'makes', 'perfect', 'drink', 'price', 'couldnt', 'lower', 'thank']
# XXX
# ['dirty', 'martini', 'makes', 'perfect', 'drink', 'price', 'couldnt', 'lower', 'thank']
# 1213
# ['makes', 'excellent', 'dirty', 'martini', 'highly', 'recommend']
# XXX
# ['makes', 'excellent', 'dirty', 'martini', 'highly', 'recommend']
# 1214
# ['coffee', 'medium', 'roast', 'natural', 'ingredients', 'ingredients', 'watercoffee', 'extractsugarmilk', 'powdersoy', 'lecithin', 'emulsifier']
# XXX
# ['coffee', 'medium', 'roast', 'natural', 'ingredients', 'ingredients', 'watercoffee', 'extractsugarmilk', 'powdersoy', 'lecithin', 'emulsifier']
# 1215
# ['surprised', 'light', 'bubbly', 'variety', 'foods', 'price', 'point', 'makes', 'great', 'sharing', 'friends', 'alike']
# XXX
# ['surprised', 'light', 'bubbly', 'variety', 'foods', 'price', 'point', 'makes', 'great', 'sharing', 'friends', 'alike']
# 1216
# ['quite', 'autodelivery', 'robust', 'smooth', 'enjoy']
# XXX
# ['quite', 'autodelivery', 'robust', 'smooth', 'enjoy']
# 1217
# ['meritage', 'smooth', 'would', 'delivery', 'purchased', 'syrah', 'havenäôt', 'tried']
# XXX
# ['meritage', 'smooth', 'would', 'delivery', 'purchased', 'syrah', 'havenäôt', 'tried']
# 1218
# ['refreshing', 'sweet', 'dessert']
# XXX
# ['refreshing', 'sweet', 'dessert']
# 1219
# ['sweet', 'brands', 'tried', 'swallow', 'comes', 'throat', 'tastes', 'bitter', 'never', 'happened', 'brands', 'sorry', 'kevin', 'oleary', 'brand', 'expensive', 'bitter', 'taste']
# XXX
# ['sweet', 'brands', 'tried', 'swallow', 'comes', 'throat', 'tastes', 'bitter', 'never', 'happened', 'brands', 'sorry', 'kevin', 'oleary', 'brand', 'expensive', 'bitter', 'taste']
# 1220
# ['bodied', 'smooth', 'meritage', 'perfect', 'blend', 'things', 'alternated', 'lately', 'pinot', 'delicious', 'perfectly', 'priced']
# XXX
# ['bodied', 'smooth', 'meritage', 'perfect', 'blend', 'things', 'alternated', 'lately', 'pinot', 'delicious', 'perfectly', 'priced']
# 1221
# ['kevin', 'oleary', 'loved', 'makes', 'delicious', 'purchased', '3bottle', 'chardonnay', 'wonderful', 'expert', 'enjoy', 'white', 'sweet', 'didnt', 'moscato', 'enjoy', 'glass', 'white', 'whenever', 'delightful', 'glass', 'necessary', 'pleased', 'purchase', 'pleased', 'purchased', 'autodelivery', 'shipment', 'highly', 'recommend', 'wonderful']
# XXX
# ['kevin', 'oleary', 'loved', 'makes', 'delicious', 'purchased', '3bottle', 'chardonnay', 'wonderful', 'expert', 'enjoy', 'white', 'sweet', 'didnt', 'moscato', 'enjoy', 'glass', 'white', 'whenever', 'delightful', 'glass', 'necessary', 'pleased', 'purchase', 'pleased', 'purchased', 'autodelivery', 'shipment', 'highly', 'recommend', 'wonderful']
# 1222
# ['ordered', 'foods', 'oleary', 'awesome', 'smooth', 'cabernet', 'usually', 'first', 'choice', 'delivery']
# XXX
# ['ordered', 'foods', 'oleary', 'awesome', 'smooth', 'cabernet', 'usually', 'first', 'choice', 'delivery']
# 1223
# ['expected', 'better', 'tasting', 'foods', 'presentation', 'sounded', 'great', 'taste', 'moscato', 'sweet', 'chardonnay', 'could', 'better', 'disappointed', 'reviewer', 'better', 'taste', 'purchasing']
# XXX
# ['expected', 'better', 'tasting', 'foods', 'presentation', 'sounded', 'great', 'taste', 'moscato', 'sweet', 'chardonnay', 'could', 'better', 'disappointed', 'reviewer', 'better', 'taste', 'purchasing']
# 1224
# ['bought', 'right', 'christmas', 'extremely', 'disappointed', 'purchase', 'dinner', 'guests', 'always', 'better', 'sample', 'making', 'purchasing', 'lesson', 'learned']
# XXX
# ['bought', 'right', 'christmas', 'extremely', 'disappointed', 'purchase', 'dinner', 'guests', 'always', 'better', 'sample', 'making', 'purchasing', 'lesson', 'learned']
# 1225
# ['never', 'ordered', 'pleasantly', 'surprised', 'ordering']
# XXX
# ['never', 'ordered', 'pleasantly', 'surprised', 'ordering']
# 1226
# ['disappointed', 'taste', 'consistency', 'foods', 'husband', 'looking', 'forward', 'sharing', 'friends', 'christmas', 'tried', 'variety', 'satisfied', 'planning']
# XXX
# ['disappointed', 'taste', 'consistency', 'foods', 'husband', 'looking', 'forward', 'sharing', 'friends', 'christmas', 'tried', 'variety', 'satisfied', 'planning']
# 1227
# ['bought', 'christmas', 'present', 'skeptical', 'first', 'first', 'really', 'leaves', 'nasty', 'taste', 'bitter', 'drinking', 'glass', 'severe', 'headache', 'anyway', 'bottle', 'ordered', 'could', 'stand', 'smell', 'totally', 'surprised', 'could', 'decided', 'smooth', 'taste', 'strong', 'bitter', 'smell', 'guests', 'years', 'enjoyed', 'probably', 'ordering']
# XXX
# ['bought', 'christmas', 'present', 'skeptical', 'first', 'first', 'really', 'leaves', 'nasty', 'taste', 'bitter', 'drinking', 'glass', 'severe', 'headache', 'anyway', 'bottle', 'ordered', 'could', 'stand', 'smell', 'totally', 'surprised', 'could', 'decided', 'smooth', 'taste', 'strong', 'bitter', 'smell', 'guests', 'years', 'enjoyed', 'probably', 'ordering']
# 1228
# ['skeptical', 'ordering', 'foods', 'figured', 'could', 'surprised', 'smooth', 'flavorful', 'beautiful']
# XXX
# ['skeptical', 'ordering', 'foods', 'figured', 'could', 'surprised', 'smooth', 'flavorful', 'beautiful']
# 1229
# ['little', 'skeptical', 'purchasing', 'surprised', 'quality', 'collection', 'ordered', 'mixedauto', 'delivery', 'package', 'moscato', 'indeed', 'sweet', 'expect', 'moscato', 'syrah', 'guess', 'outset', 'sweetfood', 'drinker', 'sweet', 'foods', 'liking', 'never', 'drink', 'chardonnay', 'likewise', 'kevin', 'olearys', 'chardonnay', 'favorite', 'entire', 'order', 'awesome', 'magnificent', 'tasty', 'ordered', 'fettuccine', 'could', 'chardonnay', 'great', 'ordered', 'autodelivery', 'spring', 'oleary']
# XXX
# ['little', 'skeptical', 'purchasing', 'surprised', 'quality', 'collection', 'ordered', 'mixedauto', 'delivery', 'package', 'moscato', 'indeed', 'sweet', 'expect', 'moscato', 'syrah', 'guess', 'outset', 'sweetfood', 'drinker', 'sweet', 'foods', 'liking', 'never', 'drink', 'chardonnay', 'likewise', 'kevin', 'olearys', 'chardonnay', 'favorite', 'entire', 'order', 'awesome', 'magnificent', 'tasty', 'ordered', 'fettuccine', 'could', 'chardonnay', 'great', 'ordered', 'autodelivery', 'spring', 'oleary']

# %%
#removing [] from reviews
for i in range(1230):
    n=clean_df_n["Full Text Reviews "][i]
    n=n.replace("[","")
    n=n.replace("]","")
    clean_df_n["Full Text Reviews "][i]=n
# Out:
# D:\programs\anaconda\lib\site-packages\ipykernel_launcher.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
clean_df_n.head()
# Out:
#    Purchased Reviews  Recommended Reviews  Rating of Reviews  \
# 0                1.0                  1.0                  5
# 1                0.0                  1.0                  5
# 2                0.0                  1.0                  5
# 3                0.0                  1.0                  5
# 4                0.0                  1.0                  5
#
#                                   Full Text Reviews   \
# 0                'sweet', 'smooth', 'taste', 'every'
# 1  'terrific', 'product', 'drops', 'straight', 'm...
# 2  'market', 'leaves', 'hoppy', 'aftertaste', 'ap...
# 3  'great', 'refreshing', 'taste', 'ingredients',...
# 4  'purchased', 'mimosas', 'mimosas', 'delicious'...
#
#                           Title of Reviews   label
# 0  I love the sweet smooth muscadine taste.      0
# 1                                Delicious!      1
# 2                   Hoppy! Best Hoppy Food.      1
# 3                           Love This Brew!      1
# 4                      Actually Quite Tasty     -1

# %%
#saving the dataframe of tokenized reviews

# %%
clean_df_n.to_csv(r"data//data_reviews_cleaned",index=False)

# %%
#retrieving the dataframe of tokenized reviews

# %%
reviews_clnd=pd.read_csv(r"data//data_reviews_cleaned_")

# %%
reviews_clnd.head()
# Out:
#    Purchased Reviews  Recommended Reviews  Rating of Reviews  \
# 0                1.0                  1.0                  5
# 1                NaN                  NaN                  5
# 2                0.0                  1.0                  5
# 3                0.0                  1.0                  5
# 4                0.0                  1.0                  5
#
#                                   Full Text Reviews   \
# 0                'sweet', 'smooth', 'taste', 'every'
# 1  'terrific', 'product', 'drops', 'straight', 'm...
# 2  'market', 'leaves', 'hoppy', 'aftertaste', 'ap...
# 3      'great', 'refreshing', 'taste', 'ingredients'
# 4  'purchased', 'mimosas', 'mimosas', 'delicious'...
#
#                           Title of Reviews   label
# 0  I love the sweet smooth muscadine taste.      0
# 1                                Delicious!      1
# 2                   Hoppy! Best Hoppy Food.      1
# 3                           Love This Brew!      0
# 4                      Actually Quite Tasty      1

# %%
#plotting word cloud using word_cloud function

# %%
_=word_cloud(reviews_clnd,1)

# %%
#plotting bar graph of top positive 7 frequent words 
_=words_freq_plot_sent(reviews_clnd,1)
